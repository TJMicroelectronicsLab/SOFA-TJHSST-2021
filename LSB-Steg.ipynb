# %%
import cv2
import numpy as np
import types

# %%
def messageToBinary(message):
  if type(message) == str:
    return ''.join([ format(ord(i), "08b") for i in message ])
  elif type(message) == bytes or type(message) == np.ndarray:
    return [ format(i, "08b") for i in message ]
  elif type(message) == int or type(message) == np.uint8:
    return format(message, "08b")
  else:
    raise TypeError("Input type not supported")

# %%
def hideData(image, secret_message):

  # calculate the maximum bytes to encode
  n_bytes = image.shape[0] * image.shape[1] * 3 // 8
  print("Maximum bytes to encode:", n_bytes)

  #Check if the number of bytes to encode is less than the maximum bytes in the image
  if len(secret_message) > n_bytes:
      raise ValueError("Error encountered insufficient bytes, need bigger image or less data !!")
  
  secret_message += "#####" # you can use any string as the delimeter

  data_index = 0
  # convert input data to binary format using messageToBinary() fucntion
  binary_secret_msg = messageToBinary(secret_message)

  data_len = len(binary_secret_msg) #Find the length of data that needs to be hidden
  for values in image:
      for pixel in values:
          # convert RGB values to binary format
          r, g, b = messageToBinary(pixel)
          # modify the least significant bit only if there is still data to store
          if data_index < data_len:
              # hide the data into least significant bit of red pixel
              pixel[0] = int(r[:-1] + binary_secret_msg[data_index], 2)
              data_index += 1
          if data_index < data_len:
              # hide the data into least significant bit of green pixel
              pixel[1] = int(g[:-1] + binary_secret_msg[data_index], 2)
              data_index += 1
          if data_index < data_len:
              # hide the data into least significant bit of  blue pixel
              pixel[2] = int(b[:-1] + binary_secret_msg[data_index], 2)
              data_index += 1
          # if data is encoded, just break out of the loop
          if data_index >= data_len:
              break

  return image

# %%
def showData(image):

  binary_data = ""
  for values in image:
      for pixel in values:
          r, g, b = messageToBinary(pixel) #convert the red,green and blue values into binary format
          binary_data += r[-1] #extracting data from the least significant bit of red pixel
          binary_data += g[-1] #extracting data from the least significant bit of red pixel
          binary_data += b[-1] #extracting data from the least significant bit of red pixel
  # split by 8-bits
  all_bytes = [ binary_data[i: i+8] for i in range(0, len(binary_data), 8) ]
  # convert from bits to characters
  decoded_data = ""
  for byte in all_bytes:
      decoded_data += chr(int(byte, 2))
      if decoded_data[-5:] == "#####": #check if we have reached the delimeter which is "#####"
          break
  #print(decoded_data)
  return decoded_data[:-5] #remove the delimeter to show the original hidden message

# %%
# Encode data into image 
def encode_text(): 
  image_name = input("Enter image name(with extension): ") 
  image = cv2.imread(image_name) # Read the input image using OpenCV-Python.
  #It is a library of Python bindings designed to solve computer vision problems. 
  
  #details of the image
  print("The shape of the image is: ",image.shape) #check the shape of image to calculate the number of bytes in it
  print("The original image is as shown below: ")
  resized_image = cv2.resize(image, (500, 500)) #resize the image as per your requirement
  display(PIL_Image.fromarray(resized_image)) #display the image
  
      
  data = input("Enter data to be encoded : ") 
  if (len(data) == 0): 
    raise ValueError('Data is empty')
  
  filename = input("Enter the name of new encoded image(with extension): ")
  encoded_image = hideData(image, data) # call the hideData function to hide the secret message into the selected image
  cv2.imwrite(filename, encoded_image)

# %%
# Decode the data in the image 
def decode_text():
  # read the image that contains the hidden image
  image_name = input("Enter the name of the steganographed image that you want to decode (with extension) :") 
  image = cv2.imread(image_name) #read the image using cv2.imread() 

  print("The Steganographed image is as shown below: ")
  resized_image = cv2.resize(image, (500, 500))  #resize the original image as per your requirement
  display(PIL_Image.fromarray(resized_image)) #display the Steganographed image
    
  text = showData(image)
  return text

# %%
# Image Steganography         
def Steganography(): 
    a = input("Image Steganography \n 1. Encode the data \n 2. Decode the data \n Your input is: ")
    userinput = int(a)
    if (userinput == 1):
      print("\nEncoding....")
      encode_text() 
          
    elif (userinput == 2):
      print("\nDecoding....") 
      print("Decoded message is " + decode_text()) 
    else: 
        raise Exception("Enter correct input")

# %%
#Let's try and Capture Webcam Data

# %%
orig_img_path = '/home/xilinx/jupyter_notebooks/common/data/webcam.jpg'
# !fswebcam  --no-banner --save {orig_img_path} -d /dev/video0 2> /dev/null

# %%
from PIL import Image as PIL_Image

img = PIL_Image.open(orig_img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=352x288 at 0xA605B1F0>

# %%
Steganography()
# Out:
# Image Steganography
#  1. Encode the data
#  2. Decode the data
#  Your input is: 1
#
# Encoding....
# Enter image name(with extension): pika.jpg
# The shape of the image is:  (500, 500, 3)
# The original image is as shown below:
# <PIL.Image.Image image mode=RGB size=500x500 at 0xA6265470>
# Enter data to be encoded : bobby
# Enter the name of new encoded image(with extension): bob.jpg
# Maximum bytes to encode: 93750

# %%
Steganography()
# Out:
# Image Steganography
#  1. Encode the data
#  2. Decode the data
#  Your input is: 2
#
# Decoding....
# Enter the name of the steganographed image that you want to decode (with extension) :bob.jpg
# The Steganographed image is as shown below:
# <PIL.Image.Image image mode=RGB size=500x500 at 0xA62D1B70>
# ÆmÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÜl÷®#£|ü·#ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿüÏx£¤³Çkkmÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿé¶¯oágý>¶8ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿú}¸LÊðû}oÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ«7ëv}u¾à_Ù-¿ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿû³~Ù°ÞI¦1ý·ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿú9»>pÃëmàÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿô¤`!
# ªÇ
# ®v­Í?¬/ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ°$­þ¥0Ì8Y£ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿùZó7
# PUFk&¤Ïúoÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ°%»hKEÁ=üR«¡>NôÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿùY¡è¾¸ Æ¥}ú3ù}¿ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ°åÞ'*/ÿúRIæ´³Sÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ.[²owuÿxµdvI»ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿø²åº[Àv
# e&H½íÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿè­GÛ}6­o÷k7
# Î
# ïülÙÂÍ4_©I;aÿ4ùÌ{mÏýÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿó¸<ÚÏªylý¬9Bd62ö¤°ü¿{ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ§m?nlÝ|¦ö*ªü07è¨<{ögµÇTù½¿ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿú¾Ø×DYÂÒrfL®LOÙÑ°-µÚ@:0`­¾ÛÛÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿwqü:.?|?Ç×ÜÓ«æ-FT°ß-íºÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ*Ò~Á#ÒO8ÔJ½Ïûo@=ò¬4È-úÿ¿ÿÿÿ¶ßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ¬4Äovmü¼1´~%·ââ>ÚY?®KlÿÛ6äÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÉ^aÛqÇöÜS½RV«m¶ÜqØÉ%®A9dVHåæØÿý²nOÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøt·+l}¶*«UI$U9·$¥±7»MÿÛ6Àÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿö;?jU9f_öaÐ¼ªITI%UXîN'ý
# ½ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛ&Û¿Òé>¦»j¶Ô©+j©ZÝÅ-æÇmZ^Ö_ßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿým³9ºAë»X´¶©Zm[Rª¤M£øÜ@î¡HuîÇg}ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÄÛØÿ¼Ý»j©[RVÛUV¥ju^c¥¦~¹´Hwßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿò@m¼x©í2Í8[¶©ZmTÝJÛm¶ÖëÊ?VÔ0$½Í÷}ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý¶Ûÿ[éÛó$mv¤­¶Ûm¶ÛmÚÐXÛ)÷¸m¥ªcßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛm¿ü&8+ý<vµ*¶¤I+m¶ÒkuL¡ÐÓYïÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÃhMÙF¼nÄm©[jI$¶ÛmÕ'KR¾¬ù´¯@ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÓ@Á­­lN¶ÕknÛm¶Ûm¶ÛM®êÉø=þ³ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý±ý>
# °ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿö+ÕA¢¬£K[j¶ÒUZ­I,NÇ]7Ðy´'öþ9RrOÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý»{|Kç»i<jÛI/ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛÀ_ªD©$­É%UI$­Äèö8Òyé=-¿ü4ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿI¿»ìgÓ6­´ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿùÝï4%º´Õm©,JÕku,Nã·FeMwðz¤ÿùOÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðýï¬¥¿O/ÛHÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿK>X¶º]Äv«R-[R¶¥m·km$Ýô9 Î-´ÚOõÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ÷ÿüä!¾ÝóOÎÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿõÙÇì­Ó[«+mªßUV¤I+v¶ÒI%#I©£+Îïu¹}ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ{?æR²ØfÛ6üïÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ_ÎGÏÿÕµJ­[UÊ¤­I$·km$Ig¼ÓëËÏÜ[¾ßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ´ÿé¤IáºÛü²?Ìÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøçnkõ&ÒJÓRI+jVëv¶ÖI$¿êèÍÆBýKÁíÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛ{î$¯ Ñ&½ãýËÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ >Û¹Üf³R­U}É[R¶¥n·k{l¢¨¶Ìàüßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý]RY¥mö?ë¿ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿök¶¹{i*ÚÕ+Ú­JÔIn´ÉIB-òÝ
# }^K¢qâÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ×ÙÐ)K
# ß¶ËcõðªÚVÕRJ«m¶êNc`ýtªC¾»ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿëû¡)E~/Ùù®Ý¥04YÐ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿýuíu´¿6¿òI)*ª©[kI$I$¹±:bÄ{|U¹m
# ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ;çN*S
# uJqû·Üÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿö{Où§*GÏ¤&@­Vª¶´I$Vê«³lÅ63ñZF¯oÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿð?ÿÿß3|cR.f·û©+üñ»ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ¸Ù®Ú{½-³«U¶ÛmI$IZKüåîoìõå·ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÁ¯AþàùKý3»kçN3ç;ÆÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿëKµ2 Îçí¤ØUm'm©TI$­V+÷ãD[ËbÆïÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿð?ücËcï¶At§µ±Ç±k¯ïÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþû$húR	¥¶mUVÒjºI$JÕiË¶fÐOF3èîí#ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿíNçË.ôF?kÃuÛC vÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿð?à=¶ó]e5îE¤µjµZª¤I$©¹ë«}zzÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿâÛ@æ×íñä Öí¯=Tì;&ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ©Ðö{¬ºqT?å²[ªÕj©:­I$I%n×ÕâV	ÊÉrîê?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿü~dÙ[ÚÁ*|©?¶·s6¹a×+YßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿûoÿôÀÿÿÿý¶Ûÿêz
# [ê·nùÚ[%¶ªªªÔI$I¿wÌ·Ä@ë÷ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿìÁ´Ðñ³*ôÿk¯=lý&µíþÿÿÿûoÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ}°'FË&»²âèÇü=<õ»rç<mÄìJµ[RªÛUª»jµ7U¶¾¿|<jß|xÑðÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿü×·^B@¶oT
# üc÷ÞÄìIV·jµ[RJÛRµ$©7j)În©Ï&Ý÷ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿüíÿÝÊÖ*£'
# |ü?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ»ër½b·DxûþlKm¶ÝÎöT~îÝqíûÿmÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛ·ý÷½Ö'ð¤qöI:ÓªÜ¼O*Ú«JÔª¶ÛmIÚ¶ÛmI$­þßöÛöþaÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþç±gÿ²úï¯3p W=»B&ÛkÜ÷3C«_Ûß¿¿ßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿýÛÿ»ü«À¡rp
# ú¦Ý¾¯ÿÿÿÿÿÿÿÿÿÿÿÿÿíöí·àÑ¶Þ´°´±Vª½3?ÖÄéî0+?þ-½Ü+é¼àJÝ?<µ¤ÛÅ¶Ý¿Çf¶8¼×ÈõÚSî `ÛöÕý¶ÛU©ÚÕJÛRn¤ªÛU¶Ú­ªÔµZ­¶Ûm¶ÛmÌeU¼I +ýÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿvùóÁ ­ãzrJÁ[UJÛRVÚÛvÚ¤SÂßÛÛÊÿÿÿÿÿÿÿÿÿÿÿÿÿÿw»snm´èWoêºQôq þê}õmTq
# ¦ÞT4£Ãÿæ}öoIñL=9 xç&CRþSm¾çn d§ÑÛÛê~Øe*ófëSzý}·?ùI%Uª¥Un¶Û®«RªÛU¶ÛjµTÚI$¶Ûm¶Ûm¶«R¶Ü©öâ	ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ}Ò½þâÇþgí¦ôáyËªI¶íJÛR¶ÔI$¶¶òsL6²ÿÿÿÿÿÿÿÿÿÿÿÿÿøÝåjC½»j½ÙZÀC üFbÀ9Üø%ÿë*HI/À×ª¾þñèßACÛ]g×ÿÿøÚZõ1
# ÔrÚïÿÿÿÿÿð±Reýô]ñ,¥æå·ñ$ëm¶×kv´­I#oÖ"9%ÃSg.÷ÿÿÿÿÿÿÿÿÿÿÿÿÿÛm¶ÛGËßû$Z©T­©%x=láÓö$ÙÛ>þU!ÛÝdÿþ­Þ4`\9åýjÚÉ®¼4ô3ßøû¨^J'©]ú@f¿.ZÝçí<J³¶ÛR¶¥mI$¶¥Uµ$­vÛ[­*íµ%jV§]µ+jµÕj©[n«&ëµ»ç8ëS-¯ÿÿÿÿÿÿe&¶:Í¹âs_FÉa>]dª¶Ûm©ZJÔÙ¶ýaÒUõ¶Û¶\ÿÿÿÿÿÿÿÿÿÿÿÿý¶Ûoóµ/û¶%mJÕV[#¹]@fÛiH©/ñª*¶þ­R½´ôÙÌmÊ Ù PEÝçç·ZZÉ¦mSÊ­ºhS]À­­×Uª´I+jU[RJÖí¶Öê¶«j®¥m®¥jµZ¶ÛmukRg´õ¿µ2ÞÿÿÿÿÿöÈOÖÝòË/ÜÄ¶6{Å[m¶ÔI$­I-¤[âåq_¸ûCIÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý¶üèÙ¹Ë¤;2ÞËÈ<(´9R~TU¤yü_Í[=òÛöSÇ§Òï#W·áÏ¼¿!.ÈÏvS©.¹dª	GÚõ¬{%µä
# ÚÝuZ«¶Ûm¶¥Uµ$­nÛmn«jiVíVÚê¶«U©»m©Z©.ÉëHmþPò?ÄÿÿÿÿÿÿÿÞZ:¹ÆrÏ®êºÂ§U¶ÛmI$JÔ&I¾_K_¶6ÇÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛaùåçýê[C±Ø³è1ÂiÿßÿÛmjµaêqæÂ¸«ßi¼²§SÞ·ÔQ+ÁöQÎvÝ¥ïVËRÄEëg#7¤>c½Ïmµ+jVÖÛm»jU[RJ×mµºÒ®ÚívµjuÛj©+]V¤V¢m[YNúÙÔOÿÿÿÿÿû|qYÙx_`q§>ºÝl[ÅÛm¶Ú©T­I"c{¦%<£°Vóÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿà/v¶)»·<É$­ bÛ|Ê¹ËÿÿÿçNMð´=ç)_Æ3ýÏý¶®Ú÷®ýNãPÐ(ÉÒ·be&ß(1G=»Ü
# ¶¥Uµª­µ$­¶Úu¥mUZUº«µÚÝ¶Úµ%jI+mIUmÅ:-üØÝÿÿÿÿÿþÚÖßÏ¹\Ð¢mß[w;-©¾}µZ­¶Ûmn¥[µ%V{¬I|EÚD¼ÿÿÿÿÿÿÿÿÿÿÿÿöÛm°Í·#{oÛÝYDÝëÀkqy{%)#oß¦ú(}ÿÌX°ïÉvíéÙÓêö]ÅÞìbòN	&þó]ýnyÑ*µ¤©%jV«m©&Ûm¾E¥Õ[qÚÝµ?lvÖÔ­µµUªÛ\ýú± ÿÿÿÿÿÿ?ÊDÐö3ÏOd¾tv¥[«Ô©+m¶ÕUªªUVö7\¬£Ü)R°?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý®ÙÒ%¶ØÉ3Ñ:.øÿ¨	Ùv¡À3Í1Ém¶'IÄþN;cÉ-¤m²ig&b>%½(üû´ÿÕßñIÙZ­Ç«vºÒVÕ[©ZªÛQm¶í×oÝ|ÑÁÿñÿm¶ÛmNÕjØÙ>wò%½qùÛ(ÛoRí+Ñ@üÆOsz§èOUU%j©Zµ'jJÛ[ª¥muM¯õÍÙ+iûR¹Æÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿù/Ô×­BàÃ'ú}íQ¸£ûÿÛvüR)$­µ%kv«mUP[FÛ&	ÕVÙzùp?çVÒµZ­UTªÕ]ª§mnÛ[µÛUªÚ­µI¶ßm>þ¤ç¶AÉ6Ùmµ%]ªÝ±-½Í²ô«ûµ¶æ}GSl¿Í®öNsR©ZªI$I*ªm$¶ÚªV÷jÅrõò¾×~{ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿüp¸é*UÍ±UÝÇñ^ér»Ñ¶æ:¤«eI$ìI¶Ûmª«m´m²iw-eæQÇgÚÚµ*­µÔ«IZ­ª¥U©*íµ»jV¥jªÛWkKn¶ÛCüx~NûNÙ 	ZªÛUdý$:ÞÂè	ñ-í¸[Ð¨ÖþôfÉé
# _ÿÿô­ÚIY0-·¤&\H²Þ»v·>Þâ
# Þï!ÝD­ªÛRV§jV»RUT­µ*ªVûmÚúõî&Þ´ÝOÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ9ÇGÜQö6?òËè0?ÊXì£%Rim¶ÉÿýI$µª-¶$jiõ½½ÄºìÝ§+ÿ*¥mITIZ­U$«i%mNºª¶¥mªÛW}I_Àü@Æ6OCÓ'úYÉZÛJ¥R{Wû»9Éµ[u¿Ì(?ìfGKÔÞ©*µ%jv¥kJª­JÛRª¥o"o·_ÏU\ðÀÿØÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý¾¹÷Úï²dyDöoíRNb«|Ym»{7ÔI*­¶ÐÛ+ÿ´âûL+ÜÉZÒ
# ÒvýUMÚJÔªÚªUZ®ÖÝV¤©*­µ}6Àÿð±ÖívÛEò%³m¶ÚªµR_þG5öå5[SsPwù¿±Û=Öoy8ãt×û,­µUjJÚ©Tª¶«mI*ªVÿÅ%K_©ömÞÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿáé¶k;ÝF{±À7¾Ùö«jµZí(¢IÅ^I$uTÒm²ÿþLé×ÅüNÿ³ý#5%jJÕjIZ­UÚªVÖíu¥m¶·mªÛUÿÿÿÛhÛ¿GUm¥ÉâÕñò[ÊÚjÛm%Þó[qÞl¹5Ø1_+þµét®íRµÚªª¤I$¶¥UI+mª¥oãºÝ¨û?öJH|çÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþ;í}^¡¦¼3Üæk*ºOîëudI+RJÚ©Z®ÐÛÿ¥¬éãßøÏþ+ÙýR©Z©$ªÕ]ª¥j­*ÝªºÛmÚ­µRI¿òrÔ7; v#ð	xÀ[bÝJÛm¶Ò]á¸Ãõ¶V8öèsRwÛõ§ÃõbÖÅ^<L6ßõ©*ëµ%RVª©TU$­µºªVñû®©B´¯4.¯ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ`=³ºèäÒq	ðØÁ¢ÞAfRÉ¡âVÔjµ\r*ÛRU*þpü4	B
# JÚÈ¦ÛmVÖÜ6ÕUµ¥ZJ«SJÕjI&ÛJµ[ªÔ«¶ÛmÄN+Òö`P@P-þ6­«k¶¤­P²ÛÒHã¸%'|®úû vtIÿpIuTI$ª¤ªJÛRªªµZ¯o«}ÚÍÆ+¾6=ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿöÀû9?ÿûï7îÀ`6Emé¢=z{ß¸ÚÚ¶ã¶¶©TªJÿédóæõÙÛ¬Ûm¶Û[µ»mVÛ]µÔªµ4­VªmÔ«Uº­J¤I%Ý	å(ºýI'??á&ÝJ»RI_ÝâGÕÆ)éòRoësuåÈEóBr¾eø¸$­I+m¶Õmµ*©T­©T­µ·Óf\ð¨_Qº_ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿm¶·ÿäJùÊk£ÊAÄ5!§isc]TmÉZµ[hðè?9±Rm·I¶ÛmnÖíVÛm­¤êJ«SVÛj¶¥m¶¥mªÔªI$n¯Æ]À	VÍüÌÙ
# þª¦íI$%ÿã¤Ó×Ù%)-túñk]Øk}»ÓWí5$I$J¤V¥jJÔVÛhÐ«{5ëÝò*KôþeÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿöÛÿkoÿñ9%Ê ÎX
# À»â>ê©'I-ïìÒY)ªJ¤ý¶¶èÃ_þàñæ}WÃÞ
# ­µo¿ì8a¢¢ÒýýVæ»m­É$I'm®«m©ZuTª«UI$¶ÚT¨des
# ÐfÎ¹ù¿îýxõS¶¥mIZvÔI$J¤ª¤U·U¶Ú«I[ÿÂùÜ
# í¶ÖíµÙW´Û
# íJÀÄ"Ø®úÛbÈ:Êîà#ÚímÈÛ6ÙöÔI$J¤­I$µ%jª¤ØRÙCv×þ5¿[lÿU-¿©ýtµ&Ec/ÿ¨ãýë)RÛ¸Û
# Dn«·î$h®¶XÿòPØÞ	½¶íu%UI$UTªI$¶Ûm®ÛXm½¶Ù*©ýÐù3­î/ÕÊï¡ÜÒ¿ÉüS¤ª¾Xz ÿoj¥RVÕjUTªµ$­U×Uµ$­JÚ­nÛmØÛrR6¤êF£$Øúm·¶ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿöÛ/þûYq7£ã¨¶,Sb	Y)øÅY$+Ó¶Q¿úëEÏìÂ@û:µïÛn×Uµ$I%UJ¤H&ë®¶ëu$$ªóc¡ÒÕplz#=­ç×g+§«-ó<vé(~IZªµUR©Z©[[¶ÛRJÛmJÖíIoÙ®löÚb£*[}ÒÓ×öÛ{oÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿäm»ÿÚ?rç²Òìîí¦@ÞÕÀK-´¯Â[$Þ';^O=àúµJ\¯¯¤Oãß½¶ÛJÚªI$UTªI$m¶Ûn·X$¶ÛeP÷½IæòµIÝëm9uq/ÞêÒîóÒznº1é$V«R©*©ZI%Rµ$­µ+mI+VÖª«_³½@ëî¤Ûm½ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðnFÛÿõîGù×'·Çõ¶Ì/âÄ]VúJªòqª61pNÉûDTÍÑÏxòýÛËm²«j¤I%UJ¤I&Ûm¶íµ²IÛm¶VÖ´ÊcRhD¾¦!2QÇê5ë£ªU5m¶¶©+RJÕm¶ÛRJÛUµ+mµg Ä³uÇÖý¾M<vöÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ%'6i/û¼¼ÜÌ?üÓ©À¼ö¶ªý[mæU;j¿nlíØ÷ê/.2ÎÝm_æ}sì¶ëÊÔ­I$UTªI$m¶ÛnÚí ­VÛn-1¤¿ÄÌÃhN}öå$h$³@Ù#us·1Ûk®»kjÔnÛ[JÚµ$­U[Rµ$8ã?º;Áª¶²ÛæþãÛÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿòR{doµy§¾Ò1ÂqTA¬
# ³¼îJ¢õ$a%âlîIVûy¢Óß'ÔØâuª¥hc`½él¯ÿ&öÉ ílRJÕmª«SvÔ­$æý¶íl³mI'jöñËÊ·åYÛÿ¯RöÅÅxQáþßä
# d:*z{MeÜKúA4ó/Òeâv:p'O`o½Î>Õ_þúInAmôèJ¾çfÀm»m¶ÖÛvñÒúÓo+AFZQdVjýµVeõ
# ÐÓ%k±È ¤ÒÌ	<xYOÇ%ÚØu]
# ûdp{Nã¹qµ7|¿	¾m$NµIµV«m¶Û¶¥mµ×UT¸s1ØOå	¤
# D½þÿ.ÝìÉÃi$JÔµ&íU¶êI+RVÚª»[vtþÞbP¿öK°	vÒÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðm»k8üs¯&ÛÛdºì6ÞÙ°ÿÿÛ²[m¿Ànm]yL<ODRfã$ÇúÕjªßüé8úRAíD¼ÈÿàÀÄû[mÚ­u6Ûm»RJÚÛu$¢E
# »©dÀoyÙÇm÷îùx
# ±Kõjv§Uª»R©VÚJ¶}Ûòrö
# ßó6ÛÖÜOÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý¶­½ÿÿÿ¾ûï¿ÿÿ¾ÿð¾ûÿÿÿÿÚ²CðÚ`Å,û[
# $¥-$±Ûj­HzÛ¿!f?Èºã	²É´ýCôI%jV­«ÒÊ-wµÝB¸r¡ê¸Ëù××U}/pjVÚªU&Ûm±ÇU¦þ.ò¤É×KþzÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÚìw ö/ö<BzÀ8åJRÛØìqªÐÿ|DJ«µÇ "qé#'%ÿI$V¥iJ4Ó{KGF»Èª­È*Óí.Ç
# `½¶BÑ)µ('ýu@qXm[Ïp¶¶ÛUVÙ6ªª³&ñ¢:¾ÄÖ*oßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþÝ·}ÞÙ_rÓÕØJ%§bq'NI_ÿÿÁJê9æø+Çó¶q²sùlìI$ª¥U&£æÄþçOyZ5Q	PhàY|Ú7I$Ón¼ýäbÛmJ§mlR[ÇîCU­·è@kîÛÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿýooÙi÷÷±S*³_ü¡­
# q'bq$ä¼B
# Û¶;i ÖòãZk´ç÷vWkjV×RJ½'oe~ß¯à[oF±ZOGñçÖñ`U&-JÔªµ[v©#Y~£N4þÖ¤¹äÿ·ý¯ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÙ´¿qòû³ãèîéÆÊjßX'N,íRRë¦ÇÑ­ÓÙ©ýó§®-ÙÏm#¶¶¥mj¥S<õyý\Åv%sfÄ
# æIVyþGlI'M¶ÞÄ»£S){vÇC£aGC!H}±I$V¥iT¦í6!i)fÛÌh4Mò=ê­¦­%|(V?Ûjª¥j´ëq¥Gy¦]{ÿþûv¿ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý·ÿÿÿÿþ3Â×ßx:<¤¯=Gçó¶$q$ä¯ábtGWÛëÄ}Þ·±²¦«j^ú+ukm¶ÜÔÞåIéZÿ mg¥yó<YùR[ùá²ª$Úë·+MÉ|èC«Ëµ/ÿÿoÿ½»ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþû°ÿÿÿL/åÓkÎP7a¹)aÄÇ¥Üÿ¶ÝFê·QU$íjBå|+Ù,þµånçbK[ø rIÒÒP¿øl!øçEpúqñv*¾£8Áæ÷*Å5Ýe¤»lmTÍÿå6Ó`6ÛÿÿÿÛoíÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿïäý/ÿÿùý$p@ÎÍm8Z'ùlq©R?þÛmÙaÛ¨±­±Ú¤ªàK`.ÂÎ7Ø}	Yd»Ñðà&lü·	'i+Ú¸#¶a\9Ev{<ð¼½qêNDªÛæ¦´6þVR4È¯ÿm¿ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþû°Ûm¿po_×Áf~I,ÀRú©Ê¬Nm¶ÛmR´-$âvJ¯ÃÕôUÑ¯Ñ<»ßÂVI$
# Íóy³lt¶»iT@#zÏëxsùf
# +ge×ò¶i l³W\:¸ñ®³ÙiéÅÿý­»[u&½UÏ£x©pÏ·Á$×ÝöèþÕ~ÿê=ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ'ÿ¯ò¯jh¥Î¹êÜ2|ØVÛm¶ªÂÍºiÂ4îöÜMÎM;Jæ£Ú>ÂèDk¦Á(Km·¹Î¿lk²ÃÕKúÒKõ³R7ºÍG¿½»ÙÚ6ýh¸Ê­	>y;×O­ÓkÛÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþÛþÏìr6ÓÛ9
# lñþãm¶ÒªU÷t&ñÌX=§"ÜÄ±ÛZªÓ2q Y.°'°ïamCÆÒ³}<ûµ;Ç»m­%¿Û5$x;°á.A¿7©¦ö{H8_v©±=Uo>OÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿûmÿÍÏÛ!©4Qw¶ôºÛ¶G%Q7²'§mÂÞdçxT1¶ñÇ¶¯_Òû²Õ}Ä:)µ$Jtö·òª&¨ç
# ¶%²öKîv=é½ÿñÆòQä^ÔÆGâúê
# ÒA5ÁUG8Ôt~ØÏqºüÜÄ»W¶Ór·cÛµ$­JÖÝn×j¶Úý¿Z^ë*{èæK£óe7ÀØã«¶¤­¨UlçK.C¿ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿæÂY,--èÖ
# 9¤fU'kRÙ¼q8âNÛDX]­sÁØþÀGOým¦9ÉÑóùô­%ð×è¿ö[m'híµÌI'RJÛkm¶Ý­»m©i8*÷¯aýa%3³#+¸IS¶:¥jJÚï|{s®Ò¹êÙûÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀÿÿÿÿÿþl+{ÞqZ
# ú¤àä7çÛÄK?)cpZ Þ$¹6Ó{fÞÑ,åòvÒNdÛol~µ$­m¶Û¶¦Û¶Úÿ	YÝPr»xÆí<L¹÷æÎ¤çm©[j·!äá·`!4ø3gÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿöûíÿÿÿÿÿÿÿ$Ûm¶ÛmmþÁ´oìç§,³ü,
# Yp~6´ÿ$I8âq(C~ÁÈ¶\úûLÏ§¶Pþ?ù}ÑÏÛÛÞ?Û¶Ûmµ$®¤e·_ÉÒT¨µ=æºL ¿û9OG­ü
# °I¨ÒÆëvÅ$·cD²ôL¦ývÚ
# ¥É$¶ÛoGû{È3ü
# À
# Õ°uý×Âõ+U¶FÝäùí~×üßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿûÿÿÿðYçwªkËu­¶û6fÊ·«84Þ1Ú¯o~áýnÿc¬Ãè?n¶Ó¶$í;«õµügÏõÓÀåmº¿¹ßÌïå[ð3IHl@§kvºªU{äÚ\Jp^#ëm¶×iÂ;^ÙßL§í\È&Þ]|*ªµ[m`c}DûñA+mÝû]ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ~ó!/[¯é®=uUcdÕU$~j¡R4¨ìv¥b1üÊE Çc'mI@½Ø½+\·ZNß>4Å(þù¬úaÚév¶ÝUªi6¶Ûmã*¤pûi¶Ô$§íOîE¡#*öyöÜYå×RªÛUwóý­ùlrMâmmÉ?ßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿñÇÿÒ}ÏjU<¯>±Ñª®HmUPMÉ-¶Ó&¡ÀØ©LöÁÞÉd	H
# v¾ñÿ¾ªÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿûoÞ®íåÚe<^íáxÒ?ÙÿÖÕØ§¶ÆÔQ¸ÕNµTj._ÿL­NY_HN;cÄà>5Çµª3ÒY²!ÛÛ5*`NÖÓä¨MíØÞÛvÄëüõjV«m¶ßÿ.&Ì²Cm<C[Ìsiªk9þú¼ð²ûË@ìNÄì]ù~ÞcÈ÷óËk)"r¿ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ·w³#æ» )¶%Æ®2vnF
# ¼Ë£mmÕ]v«mJÒOk(5@ïpsJ®ËV}¬×<±Bºi_2§Su¥J"u«úÝÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ7ºJñÁì_¤ÌoÜq'6ºDrSmÛ'²WôÂÞÞ;)üû<åë|ÛØN8qÄìNÛª³Á¸»WïIøXµ)ãúTv	¶ÚmµUûh»4±À¥d?kÉ9Á=J®'!éU]Z²]0O¿	ßÕº¿cßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿü¾ú8wH-HªUê´dYêo3ú`~íÃÝ2ãæÞÌ]ØÚ,p¬'c$í¶ÛbvØI;ð«ÖV¿'ÿ
# I
# B-ïRµI.[
# f õé®[÷¡8Ã¬_|èöÿÿÿoÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ$ÛË;ê
# ±iËéål¨_ñIñ\ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðmºã¨i>áÑ;7n»íq$ÅA¾{m¿Ý
# fH×Õlo9:bªJ{ïWõ
# r¥
# Û[n\W
# ,·£~·Ç0>Å<7o±÷çIØþÓ_8âÔÃ mÝÄÆÀm,çMÍ¼u4</Ám÷ªÿ
# >íwb[u­<4Ý©°
# H]Ê¼IÝ^o=ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛm¶ÿð¶Û[¶äÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ$Ö·³_æçGñyøÄ
# ârG².¶oÎíØ}¶ã?u'&P E
# |L?
# _í½ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿoûooJ0¢otÞE%\ß&8
# ¿ûsÙ½n<?×Ð½º{,ôÌ\$ï4&òô¡Hìpê$I983K¡!¦Y{~ù-¤ cÇP­YÑ-K¨	ízÜ¦ïFlÛøÉ5$ôíÙ4³gÔÚÉM¾ÝIZN,Ö|=ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ%å&QÒ¿Çf´6æóúzùôlöB<³¥©UlÒÔ²4¬[q¶Dír6ÙUBc'¶9æëòp´Ö=?ÅY¯X7ÖëÛHñ/Hî-¶ÿ®JÍì°~ót@-åÜRHÞH.ÓvêdX4RÁh ?g¿¿ÿßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ÷2Mû¯¸vÊ#@SnlßÅ3ï¯ñøjÓ2*nÆUµ½fâÉ	¸íY lMB²»£LýÌC/°Tg¥¸òÕV25ç[wÀÞ$=¿Õ«öÖ²ûG#`\$)$Í«ïÛm÷
# 0:¦pïõa³vÇÿþThåÝÆ5Î Aë½(¾Áa²ë¸íÂR,³IVë¿úü =©"¯&ÖÃk·m¶$J~B¶KÞF1ÄX¤«·ÇßîÿöÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðnüÄ¸ø­Þ)ç²ÃoÚê_b.ßèÃÜÿ~Ñ9ÖòdÉØ­·m ?à=¶æÇ Þ^d¹¯µà³3KÂÝì®±sg[a¶Dóú[Rßù#'a¶;n¶Ûá¼U æIt$à°õ?Æÿûoÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ%ííÕë	*Sæ'¼>Û~õûSîÁãWöÅwÞnP9ó¾HRK&l@ÕÑe}ò=MÁ4ÐcÏ$$ÉäéäÙH+üÉIHí¶ÞJÓ°ö2m¶â¾ëmFjâÍDM$ÄkÓäöØ;mí·ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÖVÙ´¶NËTRÓõÂù>; ´Ä´}ñæ_Ö¾ ;Ô%$Ø}¶Ä%n8êæw)·dECôèX2ñê¶HVêHÞt
# äÞKlm¹ÿM´ÜÛ6Ù6ÖÑ¨©5¶Õßï64»)­IÁL0×FöÛÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý´íM»t¾ÕsÕM0%&§þqÉiÈó¢ÔÌAI¬?ñ·kmI#Q<²TtÅß8×îE'K!§
# 2Xínô¾¡ÕÿßÛoÆÙª¤V¤'[RlÛv,ÛJ\>ÿÄÑ;î@XàUeÞ3{oøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛrÙ²Úrá¼ÈÐI;Z«Ï<9&Zqoä¥¾ç£¨|Ý¿m×ã$e#JÛqÛkKHê\ÖBÉÃ^ÒVSãýôã ea¼ß%­»øGm«$mÊU©Y²¨¬ª©$åÒË³÷»qË	$á·¶üÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿd¢iUùMô\øßm¶:'£Øê_¹ÿûýí÷UF«Ùõ«¤¾<ZýÇbv'\¶I¶Û%,&ÍwìV÷hÊxü-q$
# í$vÖVØ¶ÛmH­rI$ª¤W!+tÅ;Í©j¤¥[h2u¶Û`ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿð
# /µ<¿ý¼ZO_?xcøSÌ|èÐA}£Á<ÞÐºº'¸±ÇMË¦Mê}¨ï ~@'OUùùRFÓÀ-µ3JÔI$v¤J¥jI+m9É=v?ë%òL@¼ûoÿÿý¶ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ¾m¿þûïÿÿöÀÛoÿùnÒúx	ï>§)Ú{^^hsjÉÙõ®¯ÜVUEuAÀyx|*WÒ[74I8ãÛ¹z8Ô$¬®Næq²)FHR ½¬\®æ>ìòY:m6Ø­I$I'RI+jVÖ­··fÐ·N¢5Ù~½¶þÚØm¶ßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ8åÞ÷¶ý¶ÛoÉÞæ'´ïrç d)0ô-å)2;ú,È=¬ùÔ_¼û×;ÒîÕû¶ÄwåúgI»R&ßg±Égô;±'ÌåXnLq÷þ6Ô\:¤­µ$­I%Uª¥m%¶Íð»uÆÞÏ¯PöZÈ|Ý6[þ¶i¶ÿm¶Ûÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþü[mxoï½¶Ø}ÿèY[ó*p©ºâ
# x¤¶ÜWçùÚ&±.(/Sê²ßò®«mµ$­©+R©*­Ýµ)$µjafüoNú7Ë÷ß¿ýì6Ikÿ¶ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿï¶fÂ3üíºÛ}þ÷ßÏü½%4þI")ÛÔQb[ÑåØkìû2iz^ðÓþ=¼·ÏþU}+­;I;lNØÏú®ÁÓ6÷Ìz{ò¿¨³ÝúkÕ¸4qj¸3§jJÛRJÕjµ+R©VíÊ¤WkQ¥ãI©Y)Í_üük¯Þ¿ð?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþÿ;¬·Ë»	$!YúÉä.¶ëÐòN£âK\ú¥÷~TTËy@MëÆ´Z
# ôTt{
# 6'@ÇqÄìNé,Iýª_¢þÿ¢´K
# ñ IqÆç}'ï¿î}´7ç
# ^¶CTV¹ïúµUFiSð*U#±8ìNÄà¨ã½nÏõ¼@"	;ðo²Ñ(j6é¥×ú÷bÕRU±'RVÛm¶ÖmµylºC»#*ÐT°$m¯î¸àOô²ÝkÓË®M¶Ûým°ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿû¸CvÓ~^j¶ÛmÄ\]
# A|í¯nZL;UÏnü6]àÍ9À®,bÕºû<Åìó¡ñm¶Ûr:éaÏJÒ~W}IßÌµµ½¾Ñ1ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿË¬¾·¿Ý­ÆÛmºâ¹>íÛäöÅ;BqæË¡ØÑs
# 6ævÏãöÛm»$vÿyzµùÝä']ö¿%ôÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ÷ ]b«f.·¶îÿöJnézG7rFé"°­PïÞ=yÊ¦<£­PÔ	Çv8;lN$I8ÄqÛbm´qÇéÃ¥Å'ãáëN÷"¸ùc7ý»Qì2%ÁNþ¬]$´CÄr|ÊÓíÜúZðù|{¸m¶Ûm¶ÙßiRIS¶Õ3pÛ«~Ó}¸ñÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿú¿mù0iÍkrInÎõ§µ.ð3ªSsôøx<µ£]Mváûb#ÐDµIqÇc8ìq$í¶Ûm¶ÄãØâIÙ*
# æET§}K©¥RXãP?Ù9§ü}D'N;8ã$I;I8ÛlIJßÿÇªÜ·KßbYÿ2n<û	©Pvd¸)Ï]óÀæq}þÑíè2ÈyEàªqîá©ø%ºã$xom¶Ûm¶ÛjÛl-¶ýæª@©æÔÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ³ëâ}äI#vÙnõYgsæ&Ú¯äñodK¶ú6üªÕªä¸Ð,¦¹ã£½#ÿH±$¶ÄqÛI$ØìqÇRNÛªQ:¸ÙßÁÒR GÓdÛ'eePáðx§z¾>WÖãW¥wü¸¸é3#¹z·mÂF
# Ûm¶Ûm½m(6Voò@­-º¦#coüMÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿø}>¸õËdr7k¶îp»;rÍ¯e	÷¤øÖ[ì«ÓlOØqaÜÜöÊ;%âþDÛlI;IÇÛm¶8í;µÛI:¥jÆ¬kl]è# È
# ~¯	ÏäA³±Øâq$ìv'I$±$NÄ­¶Ä­¶ÜBÚ¹zÂF´XÛ8yÑ¸«_Ë¦úÃßXë'L3K³s+m%ÞC
# ¶B¤ÜOÿZªm×1Úw	!Ë)yT£}S§uY*MÈJ$I8í±'c±$IÛm¶ÇuØáÀqÊªåÒú0)U1Þ:7¬aêE8¯ÅìÜ¡ê{'êµ¹ä÷ús£±e¼&ww­¶ÛvèÝm·mm¶ÛyãÒH¤8Èëv·µØÿ}M¾)ûoû;íÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ÷þXG$!á ýò×7&fI$NÄïÉJßËÂ-F%ÁSq
# TªNbI$vÄ¶ÄâI$¶Ûlq']ý¸åUY!FÕÎd¥º`!y³lîV~kþ8ZLQÁÜtÇ½1ô
# &´¤
# ÔbõùÌ	oñøkýÿïxÊÉ­y«,uUD(xO3D£Ñ
# ÿöÛmºÜÖÛnÖÛm·#¶Ù$Fä¹m· ï7Çç¶Öí¶ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿmÿüÝ¾éòîmë§¤m¶ÛÚÞ åmÎdsD×÷¹QÎ;ÏØ¶öÆE$IÇlIØã±$I$IØã¡lq´¨±ùáKè´lT/ÔSøøÌ[çÂ'±<öD»}ÓHoÑÂo
# XXisòBI­¶Û­ÈÝ¶Ûmm¶Û;mI$n7¶Û¾ìJnßoÿÛÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ÷ ïÿm 7k»I5Ê"ÏþrH¹Ûm¸Ý­ïÿ®¢w@¢Õé8Ö?ìª¶¦;n£J¤I$ÛI$âI$¶Ûm8ëê	¸ãµÓï¤Ï
# YCÉ·áU}1Ò/9ØWif¾Xöu}ÂÆ«M¶?½Ówä¶hÎÕj8ãÚÜI$I$¶ím¶ÛÚÜm¶Û¶îBqíW@l´ß´}¶ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿí·ðÛÎµmóêÎ2Ûm¶Ûm³±ÙUknödÞW|¹yeQÛÿJ{qã¼NÛlI8¶ÛbI$¶ÛI8wöZ!o´Ü»G&o÷g¿ç<oýQùg²°ÚcmÁbl­¤^=4¡Ts²í»_Ý­Ëm¶Ù$InÖÛm¸Ý­Ë[nInç]ÿ«üSyÿ`{mÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ	~äßùxnêM+*9fDI$I;bmV¢I¹èÐ'*mkýÃ©CÊc¤/ÜÛlIØã;m±Ûm¶Û¶Äìv·m/TÈ:28AÕÈm·¼VuNÜ3¬*£I
# Z­Y%8q"ÜjWtÃÈãùüØÎÿþßÍÚÜ¶ÛmI$¶ím¶ÛÚÜ¶·$¶îp/ÞÄfºçö¶ßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿýÙ¹îÿØsóÛÌIÑcÒtÖÒ%»q)%UI:­JÜPëÔÂöÃdÊ£µ<câzþbvÄ:¢vØ¢I$]+j
# Ý¶ÿm¨­ý¯â­?l¦<VÜoýêïm(¤©¶Ùal3R 1ÑÿN;xÈ}èí8þ¬Ý­É$I$InÖÛm¸Ý­ËkrInæ5ØËnGÛmÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÃÛÿm¿ðÿöÛö°6±yæåÿÞ8¶Ï¤ùÚÔÛ¾ßj;Îkã(­;íª©#HâL;eWL®[2$òä
# ¾¿Êâµ	jê<Ø	§¢Ù@²E`Á¨Ê]Ï½lX¸Øà"rµZ¿tw}S,)Ob(î
# ÑÇ8µÊõûj¼JèdõVgeø¶$â[m¶Ûm»mnG#­ÆÛm¸Ý­ÈÝ­Ëm¶Ûk:ãq¶Û9¶·$m^[ÓD´Á©ÎyíïÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿI¶&ßõlI1ñMFÚ¼®ªíÄêÙçûJºXK[Ó\lÎÆÐ1ÈÎñm$ßióÕÜÔuwã§lI*«Àós#,Ë»¿jÑÿc±½P®ð%v&½o'm­m¶Ûm¶Û¶·$q·cm¶ÛÚÜÚÜ¶Ûm¶¹#n7m¸ä»kmÛoUÛX4B´ñ¼ÙÞÝÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿõÏ:k+íÛ¥$uk­¸:âÇ×ªÞÚI!'gj¹°eâü/Ç-µI·G&®n9F¤WW5ºçñÎ7ìeIÅaÕ2QÂÿ|ý#LY<¼qÂÛIÚI%¶Ûm¶Ûm¶ÛHë¶Km¶ØÝ­ÈÝ­É$K[¹$·[rFÜ»m¶úä
# w2{w}­ÍÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÅìä~ëm'½ó:
# )DMg¦ÚdnlJ¹HÛnHÛnInÚäm¶Û7mm¶ÛvÚã»k¶ímÉ$nÛ[­ÈÝëØÉçý¾©'Ü6ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿûY»}àfMüc(¬ÛQÓr!úJÊs®¶ÍâxB2°ß?±ìªÍ9°ãä©³4]2ª¦þâ
# mªtÚU\i¨Øc9èË<</¯²¶KÞ¨­÷û·ÊöÄçY$¹#m¶ä¸Ý­ÆÛm¶Ûm¶Ûm¶í®FÜ¹nÖÜHÛmÊÜØÎ8ÇRÖP}#oÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿm÷÷yþñ¶u[ëíû¼éj.[m¾?E&óKÚÒ É\6ßW¢ÍÞ @fÑ'DjÛj}|}=ÑE¼üDL]MqQ
# ÿû[­¶¢=7Ä7+Àªïà¶ÓÒæQDÓGà¹8iôë÷Ö_Þ{fØFÄpU,n+qHÙÞ¶åzQ	0{Dë"IOë¶·$m¶ÛÚÜmÈím¶Ûm¶Û<ëI$ ~)$Iºë®+¾ºÜ¤&HÛI 2ßw4¶ÿþßÿû{ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿñÿÿ×Ù%Û5áèFÙÖEjmw\Á¢²ØûbÁ,ßÙyÈ5+þ|TB\h{èQà8C@½Y@oZ ]%aå0h8ÿ}°jjÛm¶Ûm¸Ý­ÆÜÖÛm¶Ûm¼%$I+èÔKm»$FÛr6ãý·?m¿ûrJÛmð®%ÿZl_ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþfif½÷À|ÛYòª°3üwþjIO=}:ððP:yÙþ}Aí>ax®\
# ·$r6Ø¤»dvÖÛmÈ[·\}í?y¶ÀÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿïúÔ'kõé÷l|Äßäí¯gg06ßv[¨a§@AäÚF2[;K,ö9Ä­!ìÁmç	Ié7;ÉÃãnRml#vÖÛm¸Ý­ÆÜÖÛm¶Ûm¸í­ÖÛm°ïü¶ÓFÛrGÃKìýZë¶$cq¢\uÛ`ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþé½ýÔ÷ÍÿÛ
# _eÔÔ\´S§«ÿÛ®FÛm¶Ûm¸Ý­ÆÜÖÛm¶Ûm³ÚFÛmºÛ$pÙ$ÿ/¾üJ«m¶Ö¯{v¥ -ç´Ø)?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿý¶¾öÛ	4Û{¯ææð@Vî]¬x`¶+F# [¬pk\î;¶0V¡Dh¸.ßøýKHäÈDª¿*ºJ/ûmµºãm¶Ûm¶ÛÚÜmÈím¶Ûm¶Ûq¹$¶ÛmØdd¥¶F×}+Ò·_8ÿ¤Ê-³Å>½ÒûÓlÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÞËýqâ#Nß<Ñ­ñ¨½ôïç-H5®iá¦ZÐÜñ°XìÜ´¹:Rÿ9¢]ÆýL
# hajáèêG9~möú}ó¶ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿm¿~Òÿ%Ñ§gUä÷én·]%·]­¶ïfm¶·m¶ÛmmÛm¶ÛmnÛ_¾¾Ie²É?öÛ¦ßtö[ôòmmÞIeÛOÿ³ù´I,û´¾ë¶ÿmµÿíÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿöÛûû¾{ím®×y§·Oþßíþ³ÿüI$k¶¶Ûm¶Û¶ÖÛm¶Ûl]wóíåÝ·÷[æ÷]æÞk¶Ûm¶·Ë|¿íäöÛÿÞm=ÖøÙ'O=»m´ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ
